# %% [markdown]
# # Clean Individual File

# %%
import pandas as pd
import numpy as np 
from io import StringIO

# %%
filename = 'Copy of daily_AOD_conc_MOD04_L2_201701.txt'
with open('MODIS_data/Copy of daily_AOD_conc_MOD04_L2_201701.txt') as f:
    lines = f.readlines()
lines
# Out:
# ['Day hour min     AOD QC2     AOD QC3  conc (um/cm2) avgbinQC2 avgbinQC3\n',
#  ' 01   11  15     0.32717     0.33800       13.89036     3           3\n',
#  ' 02   10  20     0.16067     0.15500        6.06734     1           1\n',
#  ' 03   11  01     0.21500     0.21500        8.09774     0           0\n',
#  ' 05   10  50     0.29400     0.29400       10.82038     0           0\n',
#  ' 07   10  36     0.27700     0.27700       10.25618     0           0\n',
#  ' 08   11  20     0.19200     0.19200        7.25462     0           0\n',
#  ' 09   10  25     0.17500     0.16120        6.61571     0           1\n',
#  ' 10   11  06     0.21800     0.22225       10.89078     1           1\n',
#  ' 11   10  11     0.29900     0.27600       11.41530     1           1\n',
#  ' 12   10  55     0.45000     0.45000       15.53205     0           0\n',
#  ' 14   10  41     0.30000     0.30000       11.00745     0           0\n',
#  ' 15   11  25     0.28600     0.29750       18.50253     1           3\n',
#  ' 16   10  30     0.17300     0.17300        6.54374     0           0\n',
#  ' 17   11  15     0.11800     0.11800        4.44981     0           0\n',
#  ' 18   10  16     0.12000     0.12560        4.53450     0           3\n',
#  ' 18   10  20     0.11200     0.10488        4.24962     0           1\n',
#  ' 19   11  01     0.19400     0.19400        7.32445     0           0\n',
#  ' 21   10  50     0.22500     0.22500        8.47013     0           0\n',
#  ' 23   10  36     0.25900     0.25900        9.66442     0           0\n',
#  ' 24   11  20     0.31800     0.31800       17.84605     0           0\n',
#  ' 25   10  25     0.14400     0.14275        5.44455     0           1\n',
#  ' 26   11  06     0.22400     0.22400       14.33368     0           0\n',
#  ' 27   10  11        -NaN        -NaN           -NaN     5           5\n',
#  ' 28   10  55     0.21700     0.21700       10.47806     0           0\n',
#  ' 30   10  41     0.38600     0.38600       13.68487     0           0\n',
#  ' 31   11  25     0.52667     0.63744       35.32738     1           3\n']

# %%
new_lines = [line.split() for line in lines][1:]
clean_string = '\n'.join([','.join(line) for line in new_lines])

# Unorganized column names -> need to write manually
cols = ['day','hour','min','AOD_QC2','AOD_QC3','conc','avgbinQC2','avgbinQC3']

csv_string = StringIO(clean_string)
df = pd.read_csv(csv_string,names=cols)
df.head()
# Out:
#    day  hour  min  AOD_QC2  AOD_QC3      conc  avgbinQC2  avgbinQC3
# 0    1    11   15  0.32717    0.338  13.89036          3          3
# 1    2    10   20  0.16067    0.155   6.06734          1          1
# 2    3    11    1  0.21500    0.215   8.09774          0          0
# 3    5    10   50  0.29400    0.294  10.82038          0          0
# 4    7    10   36  0.27700    0.277  10.25618          0          0

# %%
date_str = filename[-10:-4] # Assume 6 chars preceding ".txt" or ".csv" ALWAYS denote date
try:
    year = int(date_str[:4])
    month = int(date_str[4:])
except ValueError:
    raise ValueError('Incorrectly Positioned date in file name')

# %%
year_col = pd.Series(np.ones(df.shape[0])*year).astype(int)
month_col = pd.Series(np.ones(df.shape[0])*month).astype(int)
df_dates = pd.DataFrame([year_col,month_col]).T
df_dates.columns=['year','month']
df_dates
# Out:
#     year  month
# 0   2017      1
# 1   2017      1
# 2   2017      1
# 3   2017      1
# 4   2017      1
# 5   2017      1
# 6   2017      1
# 7   2017      1
# 8   2017      1
# 9   2017      1
# 10  2017      1
# 11  2017      1
# 12  2017      1
# 13  2017      1
# 14  2017      1
# 15  2017      1
# 16  2017      1
# 17  2017      1
# 18  2017      1
# 19  2017      1
# 20  2017      1
# 21  2017      1
# 22  2017      1
# 23  2017      1
# 24  2017      1
# 25  2017      1

# %%
result_df = pd.concat([df_dates,df], axis=1)
# Out:
#     year  month  day  hour  min  AOD_QC2  AOD_QC3      conc  avgbinQC2  \
# 0   2017      1    1    11   15  0.32717  0.33800  13.89036          3
# 1   2017      1    2    10   20  0.16067  0.15500   6.06734          1
# 2   2017      1    3    11    1  0.21500  0.21500   8.09774          0
# 3   2017      1    5    10   50  0.29400  0.29400  10.82038          0
# 4   2017      1    7    10   36  0.27700  0.27700  10.25618          0
# 5   2017      1    8    11   20  0.19200  0.19200   7.25462          0
# 6   2017      1    9    10   25  0.17500  0.16120   6.61571          0
# 7   2017      1   10    11    6  0.21800  0.22225  10.89078          1
# 8   2017      1   11    10   11  0.29900  0.27600  11.41530          1
# 9   2017      1   12    10   55  0.45000  0.45000  15.53205          0
# 10  2017      1   14    10   41  0.30000  0.30000  11.00745          0
# 11  2017      1   15    11   25  0.28600  0.29750  18.50253          1
# 12  2017      1   16    10   30  0.17300  0.17300   6.54374          0
# 13  2017      1   17    11   15  0.11800  0.11800   4.44981          0
# 14  2017      1   18    10   16  0.12000  0.12560   4.53450          0
# 15  2017      1   18    10   20  0.11200  0.10488   4.24962          0
# 16  2017      1   19    11    1  0.19400  0.19400   7.32445          0
# 17  2017      1   21    10   50  0.22500  0.22500   8.47013          0
# 18  2017      1   23    10   36  0.25900  0.25900   9.66442          0
# 19  2017      1   24    11   20  0.31800  0.31800  17.84605          0
# 20  2017      1   25    10   25  0.14400  0.14275   5.44455          0
# 21  2017      1   26    11    6  0.22400  0.22400  14.33368          0
# 22  2017      1   27    10   11      NaN      NaN       NaN          5
# 23  2017      1   28    10   55  0.21700  0.21700  10.47806          0
# 24  2017      1   30    10   41  0.38600  0.38600  13.68487          0
# 25  2017      1   31    11   25  0.52667  0.63744  35.32738          1
#
#     avgbinQC3
# 0           3
# 1           1
# 2           0
# 3           0
# 4           0
# 5           0
# 6           1
# 7           1
# 8           1
# 9           0
# 10          0
# 11          3
# 12          0
# 13          0
# 14          3
# 15          1
# 16          0
# 17          0
# 18          0
# 19          0
# 20          1
# 21          0
# 22          5
# 23          0
# 24          0
# 25          3

# %%
def get_df(path):
    
    filename = path.split('/')[-1]
    
    with open(path) as f:
        lines = f.readlines()
    
    new_lines = [line.split() for line in lines][1:]
    clean_string = '\n'.join([','.join(line) for line in new_lines])

    # Unorganized column names -> need to write manually
    cols = ['day','hour','min','AOD_QC2','AOD_QC3','conc','avgbinQC2','avgbinQC3']

    csv_string = StringIO(clean_string)
    df = pd.read_csv(csv_string,names=cols)
    
    date_str = filename[-10:-4] # Assume 6 chars preceding ".txt" or ".csv" ALWAYS denote date
    try:
        year = int(date_str[:4])
        month = int(date_str[4:])
    except ValueError:
        raise ValueError('Incorrectly positioned date in file name')
        
    year_col = pd.Series(np.ones(df.shape[0])*year).astype(int)
    month_col = pd.Series(np.ones(df.shape[0])*month).astype(int)
    df_dates = pd.DataFrame([year_col,month_col]).T
    df_dates.columns=['year','month']
    
    return pd.concat([df_dates,df], axis=1)

# %%
get_df('MODIS_data/Copy of daily_AOD_conc_MOD04_L2_201701.txt')
# Out:
#     year  month  day  hour  min  AOD_QC2  AOD_QC3      conc  avgbinQC2  \
# 0   2017      1    1    11   15  0.32717  0.33800  13.89036          3
# 1   2017      1    2    10   20  0.16067  0.15500   6.06734          1
# 2   2017      1    3    11    1  0.21500  0.21500   8.09774          0
# 3   2017      1    5    10   50  0.29400  0.29400  10.82038          0
# 4   2017      1    7    10   36  0.27700  0.27700  10.25618          0
# 5   2017      1    8    11   20  0.19200  0.19200   7.25462          0
# 6   2017      1    9    10   25  0.17500  0.16120   6.61571          0
# 7   2017      1   10    11    6  0.21800  0.22225  10.89078          1
# 8   2017      1   11    10   11  0.29900  0.27600  11.41530          1
# 9   2017      1   12    10   55  0.45000  0.45000  15.53205          0
# 10  2017      1   14    10   41  0.30000  0.30000  11.00745          0
# 11  2017      1   15    11   25  0.28600  0.29750  18.50253          1
# 12  2017      1   16    10   30  0.17300  0.17300   6.54374          0
# 13  2017      1   17    11   15  0.11800  0.11800   4.44981          0
# 14  2017      1   18    10   16  0.12000  0.12560   4.53450          0
# 15  2017      1   18    10   20  0.11200  0.10488   4.24962          0
# 16  2017      1   19    11    1  0.19400  0.19400   7.32445          0
# 17  2017      1   21    10   50  0.22500  0.22500   8.47013          0
# 18  2017      1   23    10   36  0.25900  0.25900   9.66442          0
# 19  2017      1   24    11   20  0.31800  0.31800  17.84605          0
# 20  2017      1   25    10   25  0.14400  0.14275   5.44455          0
# 21  2017      1   26    11    6  0.22400  0.22400  14.33368          0
# 22  2017      1   27    10   11      NaN      NaN       NaN          5
# 23  2017      1   28    10   55  0.21700  0.21700  10.47806          0
# 24  2017      1   30    10   41  0.38600  0.38600  13.68487          0
# 25  2017      1   31    11   25  0.52667  0.63744  35.32738          1
#
#     avgbinQC3
# 0           3
# 1           1
# 2           0
# 3           0
# 4           0
# 5           0
# 6           1
# 7           1
# 8           1
# 9           0
# 10          0
# 11          3
# 12          0
# 13          0
# 14          3
# 15          1
# 16          0
# 17          0
# 18          0
# 19          0
# 20          1
# 21          0
# 22          5
# 23          0
# 24          0
# 25          3
