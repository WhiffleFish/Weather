# %%
import os
import netCDF4
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
def create_dataset(year, data_path):
    year = str(year)
    
    hgt_path = ''
    uwind_path = ''
    vwind_path = ''
    
    hgts_path = os.path.join(data_path,'hgts')
    uwinds_path = os.path.join(data_path,'u_winds')
    vwinds_path = os.path.join(data_path,'v_winds')
    
    for _,_, filenames in os.walk(hgts_path):
        if f"hgt.{year}.nc" in filenames:
            hgt_path = os.path.join(hgts_path,f"hgt.{year}.nc")
            
    for _,_, filenames in os.walk(uwinds_path):
        if f"uwnd.{year}.nc" in filenames:
            uwind_path = os.path.join(uwinds_path,f"uwnd.{year}.nc")
            
    for _,_, filenames in os.walk(vwinds_path):
        if f"vwnd.{year}.nc" in filenames:
            vwind_path = os.path.join(vwinds_path,f"vwnd.{year}.nc")
            
    if hgt_path and uwind_path and vwind_path:
        try:
            cdf = CDFData(hgt_path,uwind_path, vwind_path)
            return cdf
        except:
            logging.info(f'{year} IMPORT FAILURE')
    else:
        logging.info(f'Not all data found for {year}')

# %%
# 1979 - 2019

datasets = {}
for year in range(1979,2021):
    datasets[year] = create_dataset(year,DATA_PATH)
# Out:
# INFO:root: 17:46:14 - Retrieved 1979 hgt data
# INFO:root: 17:46:18 - Retrieved 1979 uwnd data
# INFO:root: 17:46:23 - Retrieved 1979 vwnd data
# INFO:root: 17:46:32 - Retrieved 1980 hgt data
# INFO:root: 17:46:37 - Retrieved 1980 uwnd data
# INFO:root: 17:46:42 - Retrieved 1980 vwnd data
# INFO:root: 17:46:50 - Retrieved 1981 hgt data
# INFO:root: 17:46:55 - Retrieved 1981 uwnd data
# INFO:root: 17:47:00 - Retrieved 1981 vwnd data
# INFO:root: 17:47:08 - Retrieved 1982 hgt data
# INFO:root: 17:47:13 - Retrieved 1982 uwnd data
# INFO:root: 17:47:18 - Retrieved 1982 vwnd data
# INFO:root: 17:47:26 - Retrieved 1983 hgt data
# INFO:root: 17:47:31 - Retrieved 1983 uwnd data
# INFO:root: 17:47:35 - Retrieved 1983 vwnd data
# INFO:root: 17:47:44 - Retrieved 1984 hgt data
# INFO:root: 17:47:49 - Retrieved 1984 uwnd data
# INFO:root: 17:47:54 - Retrieved 1984 vwnd data
# INFO:root: 17:48:02 - Retrieved 1985 hgt data
# INFO:root: 17:48:07 - Retrieved 1985 uwnd data
# INFO:root: 17:48:11 - Retrieved 1985 vwnd data
# INFO:root: 17:48:20 - Retrieved 1986 hgt data
# INFO:root: 17:48:25 - Retrieved 1986 uwnd data
# INFO:root: 17:48:29 - Retrieved 1986 vwnd data
# INFO:root: 17:48:38 - Retrieved 1987 hgt data
# INFO:root: 17:48:43 - Retrieved 1987 uwnd data
# INFO:root: 17:48:47 - Retrieved 1987 vwnd data
# INFO:root: 17:48:56 - Retrieved 1988 hgt data
# INFO:root: 17:49:01 - Retrieved 1988 uwnd data
# INFO:root: 17:49:07 - Retrieved 1988 vwnd data
# INFO:root: 17:49:16 - Retrieved 1989 hgt data
# INFO:root: 17:49:20 - Retrieved 1989 uwnd data
# INFO:root: 17:49:25 - Retrieved 1989 vwnd data
# INFO:root: 17:49:34 - Retrieved 1990 hgt data
# INFO:root: 17:49:38 - Retrieved 1990 uwnd data
# INFO:root: 17:49:43 - Retrieved 1990 vwnd data
# INFO:root: 17:49:51 - Retrieved 1991 hgt data
# INFO:root: 17:49:56 - Retrieved 1991 uwnd data
# INFO:root: 17:50:01 - Retrieved 1991 vwnd data
# INFO:root: 17:50:10 - Retrieved 1992 hgt data
# INFO:root: 17:50:14 - Retrieved 1992 uwnd data
# INFO:root: 17:50:19 - Retrieved 1992 vwnd data
# INFO:root: 17:50:28 - Retrieved 1993 hgt data
# INFO:root: 17:50:32 - Retrieved 1993 uwnd data
# INFO:root: 17:50:37 - Retrieved 1993 vwnd data
# INFO:root: 17:50:45 - Retrieved 1994 hgt data
# INFO:root: 17:50:50 - Retrieved 1994 uwnd data
# INFO:root: 17:50:55 - Retrieved 1994 vwnd data
# INFO:root: 17:51:03 - Retrieved 1995 hgt data
# INFO:root: 17:51:08 - Retrieved 1995 uwnd data
# INFO:root: 17:51:13 - Retrieved 1995 vwnd data
# INFO:root: 17:51:21 - Retrieved 1996 hgt data
# INFO:root: 17:51:26 - Retrieved 1996 uwnd data
# INFO:root: 17:51:31 - Retrieved 1996 vwnd data
# INFO:root: 17:51:39 - Retrieved 1997 hgt data
# INFO:root: 17:51:43 - Retrieved 1997 uwnd data
# INFO:root: 17:51:48 - Retrieved 1997 vwnd data
# INFO:root: 17:51:56 - Retrieved 1998 hgt data
# INFO:root: 17:52:01 - Retrieved 1998 uwnd data
# INFO:root: 17:52:05 - Retrieved 1998 vwnd data
# INFO:root: 17:52:14 - Retrieved 1999 hgt data
# INFO:root: 17:52:19 - Retrieved 1999 uwnd data
# INFO:root: 17:52:24 - Retrieved 1999 vwnd data
# INFO:root: 17:52:32 - Retrieved 2000 hgt data
# INFO:root: 17:52:36 - Retrieved 2000 uwnd data
# INFO:root: 17:52:41 - Retrieved 2000 vwnd data
# INFO:root: 17:52:49 - Retrieved 2001 hgt data
# INFO:root: 17:52:54 - Retrieved 2001 uwnd data
# INFO:root: 17:52:59 - Retrieved 2001 vwnd data
# INFO:root: 17:53:07 - Retrieved 2002 hgt data
# INFO:root: 17:53:11 - Retrieved 2002 uwnd data
# INFO:root: 17:53:16 - Retrieved 2002 vwnd data
# INFO:root: 17:53:24 - Retrieved 2003 hgt data
# INFO:root: 17:53:29 - Retrieved 2003 uwnd data
# INFO:root: 17:53:34 - Retrieved 2003 vwnd data
# INFO:root: 17:53:42 - Retrieved 2004 hgt data
# INFO:root: 17:53:47 - Retrieved 2004 uwnd data
# INFO:root: 17:53:52 - Retrieved 2004 vwnd data
# INFO:root: 17:54:00 - Retrieved 2005 hgt data
# INFO:root: 17:54:05 - Retrieved 2005 uwnd data
# INFO:root: 17:54:09 - Retrieved 2005 vwnd data
# INFO:root: 17:54:18 - Retrieved 2006 hgt data
# INFO:root: 17:54:23 - Retrieved 2006 uwnd data
# INFO:root: 17:54:27 - Retrieved 2006 vwnd data
# INFO:root: 17:54:35 - Retrieved 2007 hgt data
# INFO:root: 17:54:40 - Retrieved 2007 uwnd data
# INFO:root: 17:54:45 - Retrieved 2007 vwnd data
# INFO:root: 17:54:58 - Retrieved 2008 hgt data
# INFO:root: 17:55:03 - Retrieved 2008 uwnd data
# INFO:root: 17:55:07 - Retrieved 2008 vwnd data
# INFO:root: 17:55:16 - Retrieved 2009 hgt data
# INFO:root: 17:55:20 - Retrieved 2009 uwnd data
# INFO:root: 17:55:25 - Retrieved 2009 vwnd data
# INFO:root: 17:55:33 - Retrieved 2010 hgt data
# INFO:root: 17:55:38 - Retrieved 2010 uwnd data
# INFO:root: 17:55:43 - Retrieved 2010 vwnd data
# INFO:root:2010 IMPORT FAILURE
# INFO:root: 17:55:51 - Retrieved 2011 hgt data
# INFO:root: 17:55:56 - Retrieved 2011 uwnd data
# INFO:root: 17:56:01 - Retrieved 2011 vwnd data
# INFO:root:2011 IMPORT FAILURE
# INFO:root: 17:56:09 - Retrieved 2012 hgt data
# INFO:root: 17:56:14 - Retrieved 2012 uwnd data
# INFO:root: 17:56:18 - Retrieved 2012 vwnd data
# INFO:root:2012 IMPORT FAILURE
# INFO:root: 17:56:26 - Retrieved 2013 hgt data
# INFO:root: 17:56:31 - Retrieved 2013 uwnd data
# INFO:root: 17:56:35 - Retrieved 2013 vwnd data
# INFO:root:2013 IMPORT FAILURE
# INFO:root: 17:56:44 - Retrieved 2014 hgt data
# INFO:root: 17:56:48 - Retrieved 2014 uwnd data
# INFO:root: 17:56:53 - Retrieved 2014 vwnd data
# INFO:root:2014 IMPORT FAILURE
# INFO:root: 17:57:01 - Retrieved 2015 hgt data
# INFO:root: 17:57:05 - Retrieved 2015 uwnd data
# INFO:root: 17:57:10 - Retrieved 2015 vwnd data
# INFO:root:2015 IMPORT FAILURE
# INFO:root: 17:57:19 - Retrieved 2016 hgt data
# INFO:root: 17:57:23 - Retrieved 2016 uwnd data
# INFO:root: 17:57:28 - Retrieved 2016 vwnd data
# INFO:root:2016 IMPORT FAILURE
# INFO:root: 17:57:36 - Retrieved 2017 hgt data
# INFO:root: 17:57:41 - Retrieved 2017 uwnd data
# INFO:root: 17:57:46 - Retrieved 2017 vwnd data
# INFO:root:2017 IMPORT FAILURE
# INFO:root: 17:57:54 - Retrieved 2018 hgt data
# INFO:root: 17:57:59 - Retrieved 2018 uwnd data
# INFO:root: 17:58:03 - Retrieved 2018 vwnd data
# INFO:root:2018 IMPORT FAILURE
# INFO:root: 17:58:12 - Retrieved 2019 hgt data
# INFO:root: 17:58:16 - Retrieved 2019 uwnd data
# INFO:root: 17:58:21 - Retrieved 2019 vwnd data
# INFO:root:2019 IMPORT FAILURE
# INFO:root: 17:58:26 - Retrieved 2020 hgt data
# INFO:root: 17:58:28 - Retrieved 2020 uwnd data
# INFO:root:2020 IMPORT FAILURE

# %% [markdown]
# # Data retrieval technique
# Want to be able to easily get back data for any year
# ```
# hgts = data.get_hgts(year,mon,day)
# ```
# Data size for each year is not same -> Can't use numpy.ndarray
# - Dictionary ?

# %%
def get_hgts(year, day=None, level=None):
    
    if isinstance(day, int):
        day -= 1  
    elif isinstance(day, tuple):
        day = date_to_day((year,*day))-1
    
    if level:
        assert day, 'Day must be provided along with level'
        level -=1
    
    return np.squeeze(datasets[year].hgts[day,level])

# %%
cdf = CDFData(r"E:\WeatherData\hgts\hgt.2014.nc",r"E:\WeatherData\u_winds\uwnd.2014.nc",r"E:\WeatherData\v_winds\vwnd.2014.nc")
# Out:
# INFO:root: 18:01:43 - Retrieved 2014 hgt data
# INFO:root: 18:01:51 - Retrieved 2014 uwnd data
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-85-15bca35c7242> in <module>
# ----> 1 cdf = CDFData(r"E:\WeatherData\hgts\hgt.2014.nc",r"E:\WeatherData\u_winds\uwnd.2014.nc",r"E:\WeatherData\v_winds\vwnd.2014.nc")
#
# ~\Documents\Code\Weather\UpperAirPatterns\netCDF_Processing.py in __init__(self, hgt_path, uwind_path, vwind_path)
#      27             assert u_winds.shape == self.hgts.shape, f"wind_shape!=hgts_shape\n{u_winds.shape} != {self.hgts.shape}"
#      28             self.u_winds = u_winds
# ---> 29
#      30         if vwind_path:
#      31             (v_year, v_winds) = self.retrieve_data(vwind_path, 'vwnd')
#
# ~\Documents\Code\Weather\UpperAirPatterns\netCDF_Processing.py in retrieve_data(self, path, name)
#      47         lats = fh.variables['lat'][:].data
#      48         times = fh.variables['time'][:].data
# ---> 49         times = times - times[0]
#      50
#      51         data = fh.variables[name][:].data
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# ~\Anaconda3\lib\site-packages\numpy\ma\core.py in __add__(self, other)
#    4097         if self._delegate_binop(other):
#    4098             return NotImplemented
# -> 4099         return add(self, other)
#    4100
#    4101     def __radd__(self, other):
#
# ~\Anaconda3\lib\site-packages\numpy\ma\core.py in __call__(self, a, b, *args, **kwargs)
#    1024         with np.errstate():
#    1025             np.seterr(divide='ignore', invalid='ignore')
# -> 1026             result = self.f(da, db, *args, **kwargs)
#    1027         # Get the mask for the result
#    1028         (ma, mb) = (getmask(a), getmask(b))
#
# MemoryError: Unable to allocate 176. MiB for an array with shape (365, 12, 73, 144) and data type float32

# %%
from skimage.io import imread
from skimage.transform import resize
from skimage.filters import gaussian

# %%
DATA_ROOT = r"E:\WeatherData"

ref_date = (2012,10,28)

ref_u_winds_path = r"E:\WeatherData\u_winds\uwnd.2012.nc"
ref_v_winds_path = r"E:\WeatherData\v_winds\vwnd.2012.nc"
mask_path = r"C:/Users/Administrator/Downloads/continental_US_mask.png"

level = 6

lon0 = 220
lon1 = 340
lat0 = 20
lat1 = 70

ref_u = retrieve_loc_data(ref_u_winds_path,lon0,lon1,lat0,lat1)[date_to_day(ref_date)-1, level-1]
ref_v = retrieve_loc_data(ref_v_winds_path,lon0,lon1,lat0,lat1)[date_to_day(ref_date)-1, level-1]

mask_img = resize(imread(mask_path, as_gray=True),ref_u.shape[-2:])

# %%
def retrieve_loc_data(path, lon0, lon1, lat0, lat1):
    
    fh = Dataset(path, mode='r')
    lons = fh.variables['lon'][:].data
    lats = fh.variables['lat'][:].data
    
    if 'uwnd' in path:
        name = 'uwnd'
    else:
        name = 'vwnd'
    
    data = fh.variables[name][:].data
    
    lat_mask = ((lats >= lat0) & (lats <= lat1))

    lon_mask = ((lons >= lon0) & (lons <= lon1))

    start_lat = np.argwhere(lat_mask).min()
    end_lat = np.argwhere(lat_mask).max()

    start_lon = np.argwhere(lon_mask).min()
    end_lon = np.argwhere(lon_mask).max()

    loc_data = data[..., start_lat:end_lat+1, start_lon:end_lon+1]
    
    return loc_data


def get_score(u, v, ref_u, ref_v, mask):
    u *= mask
    u = normalize(u)
    v *= mask
    v = normalize(v)
    ref_u *= mask
    ref_u = normalize(ref_u)
    ref_v *= mask
    ref_v = normalize(ref_v)
    
    diff = np.sqrt(np.square(ref_u-u) + np.square(ref_v-v))
    
    return diff.sum()

# %%
#scores = {year1:[day1_score, day2_score, day3_score, ...]}
scores = {}

start_year = 2018
end_year = 2021

# for year in years:
for year in range(start_year, end_year):

    uwnd_path = os.path.join(DATA_ROOT,"u_winds",f'uwnd.{year}.nc')
    vwnd_path = os.path.join(DATA_ROOT,"v_winds",f'vwnd.{year}.nc')
    # retrieve data
    try:
        uwnds = retrieve_loc_data(uwnd_path,lon0,lon1,lat0,lat1)
        vwnds = retrieve_loc_data(vwnd_path,lon0,lon1,lat0,lat1)
    except:
        logging.info(f'Insufficient Data for {year}')
        print('Data Collection Fail')
        continue
    
    assert uwnds.shape == vwnds.shape
    
    scores[year] = []
    # for day in range(days):

    for day in range(uwnds.shape[0]):
        
        cur_u_winds = uwnds[day-1, level-1]
        cur_v_winds = vwnds[day-1, level-1]
        
        # scores[year].append(get_score(day))
        score = get_score(cur_u_winds, cur_v_winds, ref_u, ref_v, mask_img)
        scores[year].append(score)
    
    logging.info(f'Year {year} Complete')
# Delete scores[year] items with no entries/scores

# %%
logging.info('INFO')
